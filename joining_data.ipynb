# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd
r = pd.read_csv('bikedata.csv')
s = pd.read_csv('venues.csv')
frames = [r,s]
results = pd.concat(frames)
print(results)
# Out:
#     Unnamed: 0   latitude  longitude  extra.normal_bikes  \
# 0            0  55.744901  37.602018                 5.0
# 1            1  55.633750  37.520553                 2.0
# 2            2  55.781240  37.592390                 3.0
# 3            3  55.781785  37.614473                 6.0
# 4            4  55.789663  37.604464                 7.0
# ..         ...        ...        ...                 ...
# 9            9        NaN        NaN                 NaN
# 10          10        NaN        NaN                 NaN
# 11          11        NaN        NaN                 NaN
# 12          12        NaN        NaN                 NaN
# 13          13        NaN        NaN                 NaN
#
#     Neighbourhood Latitude  Neighbourhood Longitude               Venue  \
# 0                      NaN                      NaN                 NaN
# 1                      NaN                      NaN                 NaN
# 2                      NaN                      NaN                 NaN
# 3                      NaN                      NaN                 NaN
# 4                      NaN                      NaN                 NaN
# ..                     ...                      ...                 ...
# 9                55.744901                37.602018  Сквер на Остоженке
# 10               55.744901                37.602018    Детский Сад 1331
# 11               55.744901                37.602018         Угрюмый дуб
# 12               55.744901                37.602018    Детская Площадка
# 13               55.744901                37.602018    Детская площадка
#
#     Venue Distance  Venue Name
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ..             ...         ...
# 9            435.0        Park
# 10           446.0  Playground
# 11           446.0        Park
# 12           464.0  Playground
# 13           503.0  Playground
#
# [792 rows x 9 columns]

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.pairplot
sns.heatmap

r.describe(include='all')
r.boxplot()
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.pairplot
sns.heatmap

s.describe(include='all')
s.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3
from sqlite3 import Error

con = sqlite3.connect("lhl.db")
cur = con.cursor()

cur.execute("CREATE TABLE bikestation(color, year, style)")

res = cur.execute("SELECT name FROM sqlite_master")
res.fetchone()

cur.execute("""
    INSERT INTO bikestation VALUES
        ('Red', 1975, Toyota),
        ('Green', 1971, Nissan)
""")

con.commit()
res = cur.execute("SELECT color FROM bikestation")
res.fetchall()

con.close()

## results.to_sql('lhl.csv',connection)
## "C:\Users\sarab\OneDrive\Desktop\Python\Updated\lhldatabase.xlsx"
# def create_connection(path):
#     connection = None
#     try:
#         connection = sqlite3.connect("lhl.db")
#         print("Connection to SQLite DB successful")
#     except Error as e:
#         print(f"The error '{e}' occurred")

#     return connection
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\sarab\OneDrive\Desktop\Python\Updated\joining_data.ipynb Cell 8 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/sarab/OneDrive/Desktop/Python/Updated/joining_data.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> con = sqlite3.connect("lhl.db")
#       <a href='vscode-notebook-cell:/c%3A/Users/sarab/OneDrive/Desktop/Python/Updated/joining_data.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> cur = con.cursor()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sarab/OneDrive/Desktop/Python/Updated/joining_data.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> cur.execute("CREATE TABLE bikestation(color, year, style)")
#       <a href='vscode-notebook-cell:/c%3A/Users/sarab/OneDrive/Desktop/Python/Updated/joining_data.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> res = cur.execute("SELECT name FROM sqlite_master")
#      <a href='vscode-notebook-cell:/c%3A/Users/sarab/OneDrive/Desktop/Python/Updated/joining_data.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> res.fetchone()
#
# OperationalError: table bikestation already exists

# %%
import pandas as pd
a = pd.read_csv('citybike.csv')
a
##"C:\Users\sarab\OneDrive\Desktop\Python\Updated\citybike.csv"
# Out:
#    Unnamed: 0          0
# 0           0  55.744901
# 1           1  37.602018
# 2           2   2.000000

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
## Data from both data frames have diffrent number of columns & rows. After combining its merging & filling NaN where we have no value.
